# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Lets create synthetic data points
from sklearn.datasets import make_classification

X, y=make_classification(n_samples=1000, n_features=2, n_classes=2, n_clusters_per_class=1, n_redundant=0)

# %%
pd.DataFrame(X)
X
# Out:
# array([[ 1.1661397 ,  1.07580925],
#        [ 0.93435472,  0.14209934],
#        [-1.48575398,  1.08059425],
#        ...,
#        [ 1.06381081,  0.67985228],
#        [-1.37575258,  0.93669057],
#        [ 0.10292903,  1.00658565]], shape=(1000, 2))

# %%
pd.DataFrame(X)[0]
# Out:
# 0      1.166140
# 1      0.934355
# 2     -1.485754
# 3     -0.880991
# 4     -2.562943
#          ...
# 995   -0.873457
# 996   -0.283696
# 997    1.063811
# 998   -1.375753
# 999    0.102929
# Name: 0, Length: 1000, dtype: float64

# %%
sns.scatterplot(x = pd.DataFrame(X)[0], y = pd.DataFrame(X)[1], hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
#split
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.25, random_state=10)

# %%
#svc
from sklearn.svm import SVC
svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#predictions
y_pred = svc.predict(X_test)

from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred))
print(confusion_matrix(X_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       120
#            1       0.97      0.99      0.98       130
#
#     accuracy                           0.98       250
#    macro avg       0.98      0.98      0.98       250
# weighted avg       0.98      0.98      0.98       250
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       2 y_pred = svc.predict(X_test)
#       3
#       4 from sklearn.metrics import confusion_matrix, classification_report
#       5 print(classification_report(y_test, y_pred))
# ----> 6 print(confusion_matrix(X_test, y_pred))
#
# File c:\Users\DEEP PATHAK\master_env\master_env\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
# ...

# %%
## Lets create synthetic data points but now with n_clusters_per_class = 2
from sklearn.datasets import make_classification

X, y=make_classification(n_samples=1000, n_features=2, n_classes=2, n_clusters_per_class=2, n_redundant=0)

# %%
sns.scatterplot(x = pd.DataFrame(X)[0], y = pd.DataFrame(X)[1], hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
rbf = SVC(kernel='rbf')
rbf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred1 = svc.predict(X_test)

# %%
#predictions
print(classification_report(y_test, y_pred1))
print(confusion_matrix(X_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       120
#            1       0.97      0.99      0.98       130
#
#     accuracy                           0.98       250
#    macro avg       0.98      0.98      0.98       250
# weighted avg       0.98      0.98      0.98       250
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 #predictions
#       2 print(classification_report(y_test, y_pred1))
# ----> 3 print(confusion_matrix(X_test, y_pred1))
#
# File c:\Users\DEEP PATHAK\master_env\master_env\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
# ...

# %% [markdown]
# Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
'kernel': ['rbf']}

# %%
grid = GridSearchCV(SVC(),param_grid=param_grid, cv=5, verbose=3, refit=True)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.980 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.973 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.967 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}

# %%
#predictions
y_pred4 = grid.predict(X_test)

#predictions
print(classification_report(y_test, y_pred4))
print(confusion_matrix(X_test, y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       120
#            1       0.98      1.00      0.99       130
#
#     accuracy                           0.99       250
#    macro avg       0.99      0.99      0.99       250
# weighted avg       0.99      0.99      0.99       250
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 6
#       2 y_pred4 = grid.predict(X_test)
#       3
#       4 #predictions
#       5 print(classification_report(y_test, y_pred4))
# ----> 6 print(confusion_matrix(X_test, y_pred4))
#
# File c:\Users\DEEP PATHAK\master_env\master_env\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
# ...
